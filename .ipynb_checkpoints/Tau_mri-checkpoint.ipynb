# %%
import pandas as pd

# %% [markdown]
# #### load in tau sheet

# %%
dftau=pd.read_csv('ABC_TauPET_MRI3T_ASHST1T2_measurements_20230110.csv')
dftau.info()

# %%
# 1) For the tau table: consider more than one row per subject as a duplicate. 
# Retain only one per subject based on whichever has the the shortest date difference between tau and MRI scans

# %%
# MRI_TAU_datediff absolute value (no negatives)
#sort by shortest date difference between tau and MRI scans
# drop_duplicates(keep='first')

# %%
dftau['MRI_TAU_datediff_abs']=abs(dftau['MRI_TAU_datediff'])

# %%
dftau.sort_values(by=['INDD','MRI_TAU_datediff_abs'],inplace=True)

# %%
dftau.drop_duplicates(subset=['INDD'],keep='first',inplace=True)

# %%
dftau.info()

# %%
##check data types for merge
for col in dftau.columns:
    print(f'{col}, {type(col)}')

# %%
for col in dftau.columns:
    if 'DATE' in col:
        print(col)
        print(type(col))

# %% [markdown]
# #### load in amyloid consensus sheet

# %%
dfamycons=pd.read_csv('allamyloid_20230109_compSUVR_AmyConsensus3.csv')
dfamycons.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 388 entries, 0 to 387
# Columns: 138 entries, INDD to Amyloid_Consensus_Comments
# dtypes: float64(128), object(10)
# memory usage: 418.4+ KB

# %%
for col in dfamycons.columns:
    print(f'{col}, {type(col)}')

# %%
##include mridate for mri sheet
dfamysmall=dfamycons[['INDD','AMYLOIDDATE','MRIDATE','Amyloid_consensus','Amyloid_Consensus_Comments']]
dfamysmall.head()
# Out:
#      INDD  AMYLOIDDATE     MRIDATE Amyloid_consensus  \
# 0  118711   20171026.0  20160412.0          Negative
# 1  120686   20170414.0  20160414.0          Negative
# 2  120686   20201208.0         NaN          Negative
# 3  107196   20170331.0  20160419.0          Negative
# 4  107196   20190129.0  20181205.0          Negative
#
#                           Amyloid_Consensus_Comments
# 0                                                NaN
# 1                                                NaN
# 2  Amyloid consensus used clinical read, no quant...
# 3                                                NaN
# 4                                                NaN

# %%
##amyloid date only for tau sheet
dfamysmall2=dfamycons[['INDD','AMYLOIDDATE','Amyloid_consensus','Amyloid_Consensus_Comments']]
dfamysmall2.head()

# %% [markdown]
# #### Add amyloid consensus status to tau spreadsheet

# %%
dftau2=pd.merge(dftau,dfamysmall2,how='left',on=['INDD', 'AMYLOIDDATE'])
dftau2.info()

# %%
dftau2.to_csv('ABC_TauPET_MRI3T_ASHST1T2_measurements_20230110_closestTau3.csv',index=False,header=True)

# %%
for index,row in dftau2.iterrows():
    if pd.isna(dftau2.loc[index,'Amyloid_consensus']):
        print(f'{row["INDD"]},{row["MRIDATE"]}')

# %% [markdown]
# #### Load MRI sheet

# %%
dfmri=pd.read_csv('ABC_MRI3T_ASHST1T2_measurements_20230112.csv')
dfmri.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 706 entries, 0 to 705
# Columns: 283 entries, ID to END
# dtypes: float64(247), int64(2), object(34)
# memory usage: 1.5+ MB

# %%
#  For the MRI table: again retain one row per subject based on 
# a) whichever one is closest to the amyloid_consensus date:
    # keep line that has dates closest to dates from amyloid_consensus sheet
# b) if they don't have amyloid status, retain the latest.
    # keep line with most recent mri
    
# amyloid date and date diff in columns IT and IU

# %%
##add date difference (rough)
for index, row in dfmri.iterrows():
    if pd.isna(dfmri.loc[index,'AMYLOIDDATE']):
        continue
    else:
        diff=abs(row['AMYLOIDDATE']-row['SCANDATE'])
        dfmri.at[index,'date_diff_rough']=abs(row['AMYLOIDDATE']-row['SCANDATE'])

# %%
#check data type for merge compatability
for col in dfmri.columns:
    print(f'{col}, {type(col)}')
# Out:
# ID, <class 'str'>
# SCANDATE, <class 'str'>
# ScanType, <class 'str'>
# ICV_ASHST1_3T, <class 'str'>
# L_Modi_Rater_T1_3T, <class 'str'>
# R_Modi_Rater_T1_3T, <class 'str'>
# QC_MRI_T1, <class 'str'>
# QC_ICV_T1, <class 'str'>
# QC_Seg_left_usegray_ASHST1_3T, <class 'str'>
# QC_Seg_right_usegray_ASHST1_3T, <class 'str'>
# QC_Edits_left_ASHST1_3T, <class 'str'>
# QC_Edits_right_ASHST1_3T, <class 'str'>
# QC_Exclude_left_ASHST1_3T, <class 'str'>
# QC_Exclude_right_ASHST1_3T, <class 'str'>
# QC_CheckOrigSpace_ASHST1_3T, <class 'str'>
# L_AHippo_VOL_ASHST1_3T, <class 'str'>
# L_PHippo_VOL_ASHST1_3T, <class 'str'>
# L_ERC_VOL_ASHST1_3T, <class 'str'>
# L_BA35_VOL_ASHST1_3T, <class 'str'>
# L_BA36_VOL_ASHST1_3T, <class 'str'>
# L_PHC_VOL_ASHST1_3T, <class 'str'>
# R_AHippo_VOL_ASHST1_3T, <class 'str'>
# R_PHippo_VOL_ASHST1_3T, <class 'str'>
# R_ERC_VOL_ASHST1_3T, <class 'str'>
# R_BA35_VOL_ASHST1_3T, <class 'str'>
# R_BA36_VOL_ASHST1_3T, <class 'str'>
# R_PHC_VOL_ASHST1_3T, <class 'str'>
# M_AHippo_VOL_ASHST1_3T, <class 'str'>
# M_PHippo_VOL_ASHST1_3T, <class 'str'>
# M_ERC_VOL_ASHST1_3T, <class 'str'>
# M_BA35_VOL_ASHST1_3T, <class 'str'>
# M_BA36_VOL_ASHST1_3T, <class 'str'>
# M_PHC_VOL_ASHST1_3T, <class 'str'>
# L_Hippo_MeanTHK_MSTTHKMT_ASHST1_3T, <class 'str'>
# L_ERC_MeanTHK_MSTTHKMT_ASHST1_3T, <class 'str'>
# L_BA35_MeanTHK_MSTTHKMT_ASHST1_3T, <class 'str'>
# L_BA36_MeanTHK_MSTTHKMT_ASHST1_3T, <class 'str'>
# L_PHC_MeanTHK_MSTTHKMT_ASHST1_3T, <class 'str'>
# L_Hippo_MedianTHK_MSTTHKMT_ASHST1_3T, <class 'str'>
# L_ERC_MedianTHK_MSTTHKMT_ASHST1_3T, <class 'str'>
# L_BA35_MedianTHK_MSTTHKMT_ASHST1_3T, <class 'str'>
# L_BA36_MedianTHK_MSTTHKMT_ASHST1_3T, <class 'str'>
# L_PHC_MedianTHK_MSTTHKMT_ASHST1_3T, <class 'str'>
# R_Hippo_MeanTHK_MSTTHKMT_ASHST1_3T, <class 'str'>
# R_ERC_MeanTHK_MSTTHKMT_ASHST1_3T, <class 'str'>
# R_BA35_MeanTHK_MSTTHKMT_ASHST1_3T, <class 'str'>
# R_BA36_MeanTHK_MSTTHKMT_ASHST1_3T, <class 'str'>
# R_PHC_MeanTHK_MSTTHKMT_ASHST1_3T, <class 'str'>
# R_Hippo_MedianTHK_MSTTHKMT_ASHST1_3T, <class 'str'>
# R_ERC_MedianTHK_MSTTHKMT_ASHST1_3T, <class 'str'>
# R_BA35_MedianTHK_MSTTHKMT_ASHST1_3T, <class 'str'>
# R_BA36_MedianTHK_MSTTHKMT_ASHST1_3T, <class 'str'>
# R_PHC_MedianTHK_MSTTHKMT_ASHST1_3T, <class 'str'>
# M_Hippo_MeanTHK_MSTTHKMT_ASHST1_3T, <class 'str'>
# M_ERC_MeanTHK_MSTTHKMT_ASHST1_3T, <class 'str'>
# M_BA35_MeanTHK_MSTTHKMT_ASHST1_3T, <class 'str'>
# M_BA36_MeanTHK_MSTTHKMT_ASHST1_3T, <class 'str'>
# M_PHC_MeanTHK_MSTTHKMT_ASHST1_3T, <class 'str'>
# M_Hippo_MedianTHK_MSTTHKMT_ASHST1_3T, <class 'str'>
# M_ERC_MedianTHK_MSTTHKMT_ASHST1_3T, <class 'str'>
# M_BA35_MedianTHK_MSTTHKMT_ASHST1_3T, <class 'str'>
# M_BA36_MedianTHK_MSTTHKMT_ASHST1_3T, <class 'str'>
# M_PHC_MedianTHK_MSTTHKMT_ASHST1_3T, <class 'str'>
# L_BA35BA36_MeanTHK_MSTTHKMT_ASHST1_3T, <class 'str'>
# L_BA35BA36_MedianTHK_MSTTHKMT_ASHST1_3T, <class 'str'>
# R_BA35BA36_MeanTHK_MSTTHKMT_ASHST1_3T, <class 'str'>
# R_BA35BA36_MedianTHK_MSTTHKMT_ASHST1_3T, <class 'str'>
# M_BA35BA36_MeanTHK_MSTTHKMT_ASHST1_3T, <class 'str'>
# M_BA35BA36_MedianTHK_MSTTHKMT_ASHST1_3T, <class 'str'>
# L_Hippo_MedianTHK_MSTFitQuality_ASHST1_3T, <class 'str'>
# L_ERC_MedianTHK_MSTFitQuality_ASHST1_3T, <class 'str'>
# L_BA35_MedianTHK_MSTFitQuality_ASHST1_3T, <class 'str'>
# L_BA36_MedianTHK_MSTFitQuality_ASHST1_3T, <class 'str'>
# L_PHC_MedianTHK_MSTFitQuality_ASHST1_3T, <class 'str'>
# L_ALL_MedianTHK_MSTFitQuality_ASHST1_3T, <class 'str'>
# R_Hippo_MedianTHK_MSTFitQuality_ASHST1_3T, <class 'str'>
# R_ERC_MedianTHK_MSTFitQuality_ASHST1_3T, <class 'str'>
# R_BA35_MedianTHK_MSTFitQuality_ASHST1_3T, <class 'str'>
# R_BA36_MedianTHK_MSTFitQuality_ASHST1_3T, <class 'str'>
# R_PHC_MedianTHK_MSTFitQuality_ASHST1_3T, <class 'str'>
# R_ALL_MedianTHK_MSTFitQuality_ASHST1_3T, <class 'str'>
# L_Modi_Rater_T2_3T, <class 'str'>
# R_Modi_Rater_T2_3T, <class 'str'>
# L_QA1_ASHST2_3T, <class 'str'>
# L_QA2_ASHST2_3T, <class 'str'>
# L_QA3_ASHST2_3T, <class 'str'>
# L_QA_COMMENT_ASHST2_3T, <class 'str'>
# R_QA1_ASHST2_3T, <class 'str'>
# R_QA2_ASHST2_3T, <class 'str'>
# R_QA3_ASHST2_3T, <class 'str'>
# R_QA_COMMENT_ASHST2_3T, <class 'str'>
# L_CA1_NSlice_ASHST2_3T, <class 'str'>
# L_CA2_NSlice_ASHST2_3T, <class 'str'>
# L_DG_NSlice_ASHST2_3T, <class 'str'>
# L_CA3_NSlice_ASHST2_3T, <class 'str'>
# L_Tail_NSlice_ASHST2_3T, <class 'str'>
# L_SUB_NSlice_ASHST2_3T, <class 'str'>
# L_ERC_NSlice_ASHST2_3T, <class 'str'>
# L_BA35_NSlice_ASHST2_3T, <class 'str'>
# L_BA36_NSlice_ASHST2_3T, <class 'str'>
# L_PHC_NSlice_ASHST2_3T, <class 'str'>
# R_CA1_NSlice_ASHST2_3T, <class 'str'>
# R_CA2_NSlice_ASHST2_3T, <class 'str'>
# R_DG_NSlice_ASHST2_3T, <class 'str'>
# R_CA3_NSlice_ASHST2_3T, <class 'str'>
# R_Tail_NSlice_ASHST2_3T, <class 'str'>
# R_SUB_NSlice_ASHST2_3T, <class 'str'>
# R_ERC_NSlice_ASHST2_3T, <class 'str'>
# R_BA35_NSlice_ASHST2_3T, <class 'str'>
# R_BA36_NSlice_ASHST2_3T, <class 'str'>
# R_PHC_NSlice_ASHST2_3T, <class 'str'>
# L_CA1_VOL_ASHST2_3T, <class 'str'>
# L_CA2_VOL_ASHST2_3T, <class 'str'>
# L_DG_VOL_ASHST2_3T, <class 'str'>
# L_CA3_VOL_ASHST2_3T, <class 'str'>
# L_Tail_VOL_ASHST2_3T, <class 'str'>
# L_SUB_VOL_ASHST2_3T, <class 'str'>
# L_ERC_VOL_ASHST2_3T, <class 'str'>
# L_BA35_VOL_ASHST2_3T, <class 'str'>
# L_BA36_VOL_ASHST2_3T, <class 'str'>
# L_PHC_VOL_ASHST2_3T, <class 'str'>
# R_CA1_VOL_ASHST2_3T, <class 'str'>
# R_CA2_VOL_ASHST2_3T, <class 'str'>
# R_DG_VOL_ASHST2_3T, <class 'str'>
# R_CA3_VOL_ASHST2_3T, <class 'str'>
# R_Tail_VOL_ASHST2_3T, <class 'str'>
# R_SUB_VOL_ASHST2_3T, <class 'str'>
# R_ERC_VOL_ASHST2_3T, <class 'str'>
# R_BA35_VOL_ASHST2_3T, <class 'str'>
# R_BA36_VOL_ASHST2_3T, <class 'str'>
# R_PHC_VOL_ASHST2_3T, <class 'str'>
# M_CA1_VOL_ASHST2_3T, <class 'str'>
# M_CA2_VOL_ASHST2_3T, <class 'str'>
# M_DG_VOL_ASHST2_3T, <class 'str'>
# M_CA3_VOL_ASHST2_3T, <class 'str'>
# M_Tail_VOL_ASHST2_3T, <class 'str'>
# M_SUB_VOL_ASHST2_3T, <class 'str'>
# M_ERC_VOL_ASHST2_3T, <class 'str'>
# M_BA35_VOL_ASHST2_3T, <class 'str'>
# M_BA36_VOL_ASHST2_3T, <class 'str'>
# M_PHC_VOL_ASHST2_3T, <class 'str'>
# L_CA_MeanTHK_MSTTHKMT_ASHST2_3T, <class 'str'>
# L_TAIL_MeanTHK_MSTTHKMT_ASHST2_3T, <class 'str'>
# L_SUB_MeanTHK_MSTTHKMT_ASHST2_3T, <class 'str'>
# L_ERC_MeanTHK_MSTTHKMT_ASHST2_3T, <class 'str'>
# L_BA35_MeanTHK_MSTTHKMT_ASHST2_3T, <class 'str'>
# L_BA36_MeanTHK_MSTTHKMT_ASHST2_3T, <class 'str'>
# L_PHC_MeanTHK_MSTTHKMT_ASHST2_3T, <class 'str'>
# L_CA_MedianTHK_MSTTHKMT_ASHST2_3T, <class 'str'>
# L_TAIL_MedianTHK_MSTTHKMT_ASHST2_3T, <class 'str'>
# L_SUB_MedianTHK_MSTTHKMT_ASHST2_3T, <class 'str'>
# L_ERC_MedianTHK_MSTTHKMT_ASHST2_3T, <class 'str'>
# L_BA35_MedianTHK_MSTTHKMT_ASHST2_3T, <class 'str'>
# L_BA36_MedianTHK_MSTTHKMT_ASHST2_3T, <class 'str'>
# L_PHC_MedianTHK_MSTTHKMT_ASHST2_3T, <class 'str'>
# R_CA_MeanTHK_MSTTHKMT_ASHST2_3T, <class 'str'>
# R_TAIL_MeanTHK_MSTTHKMT_ASHST2_3T, <class 'str'>
# R_SUB_MeanTHK_MSTTHKMT_ASHST2_3T, <class 'str'>
# R_ERC_MeanTHK_MSTTHKMT_ASHST2_3T, <class 'str'>
# R_BA35_MeanTHK_MSTTHKMT_ASHST2_3T, <class 'str'>
# R_BA36_MeanTHK_MSTTHKMT_ASHST2_3T, <class 'str'>
# R_PHC_MeanTHK_MSTTHKMT_ASHST2_3T, <class 'str'>
# R_CA_MedianTHK_MSTTHKMT_ASHST2_3T, <class 'str'>
# R_TAIL_MedianTHK_MSTTHKMT_ASHST2_3T, <class 'str'>
# R_SUB_MedianTHK_MSTTHKMT_ASHST2_3T, <class 'str'>
# R_ERC_MedianTHK_MSTTHKMT_ASHST2_3T, <class 'str'>
# R_BA35_MedianTHK_MSTTHKMT_ASHST2_3T, <class 'str'>
# R_BA36_MedianTHK_MSTTHKMT_ASHST2_3T, <class 'str'>
# R_PHC_MedianTHK_MSTTHKMT_ASHST2_3T, <class 'str'>
# M_CA_MeanTHK_MSTTHKMT_ASHST2_3T, <class 'str'>
# M_TAIL_MeanTHK_MSTTHKMT_ASHST2_3T, <class 'str'>
# M_SUB_MeanTHK_MSTTHKMT_ASHST2_3T, <class 'str'>
# M_ERC_MeanTHK_MSTTHKMT_ASHST2_3T, <class 'str'>
# M_BA35_MeanTHK_MSTTHKMT_ASHST2_3T, <class 'str'>
# M_BA36_MeanTHK_MSTTHKMT_ASHST2_3T, <class 'str'>
# M_PHC_MeanTHK_MSTTHKMT_ASHST2_3T, <class 'str'>
# M_CA_MedianTHK_MSTTHKMT_ASHST2_3T, <class 'str'>
# M_TAIL_MedianTHK_MSTTHKMT_ASHST2_3T, <class 'str'>
# M_SUB_MedianTHK_MSTTHKMT_ASHST2_3T, <class 'str'>
# M_ERC_MedianTHK_MSTTHKMT_ASHST2_3T, <class 'str'>
# M_BA35_MedianTHK_MSTTHKMT_ASHST2_3T, <class 'str'>
# M_BA36_MedianTHK_MSTTHKMT_ASHST2_3T, <class 'str'>
# M_PHC_MedianTHK_MSTTHKMT_ASHST2_3T, <class 'str'>
# L_CA_FitQuality_THKFITQUALITY_ASHST2_3T, <class 'str'>
# L_TAIL_FitQuality_THKFITQUALITY_ASHST2_3T, <class 'str'>
# L_SUB_FitQuality_THKFITQUALITY_ASHST2_3T, <class 'str'>
# L_ERC_FitQuality_THKFITQUALITY_ASHST2_3T, <class 'str'>
# L_BA35_FitQuality_THKFITQUALITY_ASHST2_3T, <class 'str'>
# L_BA36_FitQuality_THKFITQUALITY_ASHST2_3T, <class 'str'>
# L_PHC_FitQuality_THKFITQUALITY_ASHST2_3T, <class 'str'>
# L_All_FitQuality_THKFITQUALITY_ASHST2_3T, <class 'str'>
# R_CA_FitQuality_THKFITQUALITY_ASHST2_3T, <class 'str'>
# R_TAIL_FitQuality_THKFITQUALITY_ASHST2_3T, <class 'str'>
# R_SUB_FitQuality_THKFITQUALITY_ASHST2_3T, <class 'str'>
# R_ERC_FitQuality_THKFITQUALITY_ASHST2_3T, <class 'str'>
# R_BA35_FitQuality_THKFITQUALITY_ASHST2_3T, <class 'str'>
# R_BA36_FitQuality_THKFITQUALITY_ASHST2_3T, <class 'str'>
# R_PHC_FitQuality_THKFITQUALITY_ASHST2_3T, <class 'str'>
# R_All_FitQuality_THKFITQUALITY_ASHST2_3T, <class 'str'>
# YOB, <class 'str'>
# Race, <class 'str'>
# Ethnicity, <class 'str'>
# Sex, <class 'str'>
# Education, <class 'str'>
# AgeatMRI, <class 'str'>
# MRIDate, <class 'str'>
# MRIProtocol, <class 'str'>
# Scanner, <class 'str'>
# Dx_Date, <class 'str'>
# Dx, <class 'str'>
# TestDate, <class 'str'>
# AgeatTest, <class 'str'>
# MOCATOTS, <class 'str'>
# CRAFTURS, <class 'str'>
# UDSBENTC, <class 'str'>
# DIGFORSL, <class 'str'>
# DIGBACLS, <class 'str'>
# ANIMALS, <class 'str'>
# VEG, <class 'str'>
# TRAILA, <class 'str'>
# TRAILB, <class 'str'>
# CRAFTDRE, <class 'str'>
# UDSBENTD, <class 'str'>
# MINTTOTS, <class 'str'>
# UDSVERFC, <class 'str'>
# UDSVERLC, <class 'str'>
# WordListMemoryTrial1, <class 'str'>
# WordListMemoryTrial2, <class 'str'>
# WordListMemoryTrial3, <class 'str'>
# WordListMemoryTotal, <class 'str'>
# ClockDraw, <class 'str'>
# WordListRecallTotal, <class 'str'>
# WordListRecognitionYes, <class 'str'>
# WordListRecognitionNo, <class 'str'>
# WTARRaw, <class 'str'>
# MMSEConversion, <class 'str'>
# MOCATOTS_Z, <class 'str'>
# DIGFORSL_Z, <class 'str'>
# DIGBACLS_Z, <class 'str'>
# TRAILA_C2_Z, <class 'str'>
# TRAILB_C2_Z, <class 'str'>
# ClockDraw_Z, <class 'str'>
# UDSBENTC_Z, <class 'str'>
# UDSBENTD_Z, <class 'str'>
# CRAFTVRS_Z, <class 'str'>
# CRAFTURS_Z, <class 'str'>
# CRAFTDVR_Z, <class 'str'>
# CRAFTDRE_Z, <class 'str'>
# WordListMemoryTotal_Z, <class 'str'>
# WordListRecallTotal_Z, <class 'str'>
# WordListRecognitionTotal_Z, <class 'str'>
# MINTTOTS_Z, <class 'str'>
# ANIMALS_Z, <class 'str'>
# VEG_Z, <class 'str'>
# UDSVERFC_Z, <class 'str'>
# UDSVERLC_Z, <class 'str'>
# UDSVERTN_Z, <class 'str'>
# TestYear, <class 'str'>
# AMYLOIDDATE, <class 'str'>
# AMYLOID_MRI_datediff, <class 'str'>
# AMYLOIDTRACER, <class 'str'>
# compSUVR, <class 'str'>
# SampleDate_PlasmaNfL, <class 'str'>
# PlasmaNfL (pg/mL), <class 'str'>
# SampleDate_PlasmaPtau, <class 'str'>
# Plasmap-Tau181 (pg/mL), <class 'str'>
# SampleDate_PlasmaGFAP, <class 'str'>
# PlasmaGFAP (pg/mL), <class 'str'>
# APOE, <class 'str'>
# TestDate_CDR, <class 'str'>
# Memory, <class 'str'>
# Orientation, <class 'str'>
# Judgment, <class 'str'>
# Community, <class 'str'>
# Hobbies, <class 'str'>
# PersonalCare, <class 'str'>
# CDRSum, <class 'str'>
# Behavior, <class 'str'>
# Language, <class 'str'>
# SupplimentTotal, <class 'str'>
# CDRTotal, <class 'str'>
# GlobalCDR, <class 'str'>
# END, <class 'str'>
# date_diff_rough, <class 'str'>

# %%
#match column names to amycons df column names
dfmri.rename(columns={'ID':"INDD",'SCANDATE':'MRIDATE'},inplace=True)

# %% [markdown]
# #### Add amyloid consensus to mri sheet

# %%
dfmricons=pd.merge(dfmri,dfamysmall,how='left', on=['INDD', 'AMYLOIDDATE','MRIDATE'])
dfmricons.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 706 entries, 0 to 705
# Columns: 286 entries, INDD to Amyloid_Consensus_Comments
# dtypes: float64(248), int64(2), object(36)
# memory usage: 1.5+ MB

# %%
dfmricons.sort_values(by=['INDD','MRIDATE'],ascending=False,inplace=True)
##most recent MRIDATE will be first

# %%
dfmricons.sort_values(by=['INDD','Amyloid_consensus'],inplace=True)
##any value in amycons. will be sorted above NaN, 
#any amycons values or the most recent MRI date will be first for each ID grouping

# %%
dfmricons.drop_duplicates(['INDD'],keep='first',inplace=True)
dfmricons.info()

# %%
dfmricons.to_csv('ABC_MRI3T_ASHST1T2_measurements_20230109_closestAmyloid4.csv',index=False,header=True)

# %% [markdown]
# #### MRI data version 2 based on amy consensus positive/negative:

# %%
#if amyloid positive, pick an MRI after the amyloid scan date, 
# and pick an MRI before amyloid scan date if amyloid negative). 
# The logic is that people don't usually revert status, 
# so if MRI is before a negative scan, we can safely consider them negative at the time of MRI and vice versa.
    
# subject list
# for each subject
#     print lines of df where ID==subject
#     look at amy consensus
#     print amy cons results
#     if amycons == pos
#         review MRI dates, 
#         keep most recent MRI data
#     if amycons==neg:
#         revew MRI date,
#         keep MRI date that's most close to before amyloid date

# %%
dfmricons.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 706 entries, 0 to 705
# Columns: 286 entries, INDD to Amyloid_Consensus_Comments
# dtypes: float64(248), int64(2), object(36)
# memory usage: 1.5+ MB

# %%
sublist=dfmricons['INDD']

# %%
sublist.drop_duplicates(keep='first',inplace=True)
sublist.reset_index(drop=True,inplace=True)
sublist.keys()

# %%
fornewdf=[]
for index in range(0,len(sublist)):
    subjectdf=dfmricons.loc[dfmricons['INDD']==sublist[index]]
    amyconslist=subjectdf['Amyloid_consensus'].values
    
    if "Negative" in amyconslist and "Positive" in amyconslist or 'Inconclusive'in amyconslist:
    ##use most recent amyloid date with consensus (only applies to 4 subjects)
        print("uh-oh")
        print(sublist[index])
        subjectdf.sort_values('MRIDATE',ascending=False,inplace=True)
        print(subjectdf[['MRIDATE','AMYLOIDDATE','Amyloid_consensus','Amyloid_Consensus_Comments']])
        fornewdf.append(subjectdf.iloc[0])

    elif "Positive" in amyconslist:
        #ID index number of line with biggest(most recent) MRI date
        subjectdfsort=subjectdf.sort_values('MRIDATE',ascending=False) ##biggest/most recent first 
        subjectdfsort.reset_index(drop=True,inplace=True)
        rowtoadd=subjectdfsort.iloc[0,:]
        #add amycons to that line if not there already
        if pd.isna(rowtoadd.loc['Amyloid_consensus']):
            rowtoadd.at['Amyloid_consensus']='Positive'
            rowtoadd.at['Amyloid_Consensus_Comments']='amyloid consensus derived from previous scans'
        #add row to list
        fornewdf.append(rowtoadd)
    
    elif "Negative" in amyconslist:
        #which amyloid dates have a consensus recorded?
        #if just one date has consensus, use that one
            #then mridate that is before that date
        #if more than one date has consensus, use the most recent amyloid date
            #then mridate that is before that date
        listforloop=[]
        for index, row in subjectdf.iterrows():
            if not pd.isna(subjectdf.loc[index,'Amyloid_consensus']):
                listforloop.append(row['AMYLOIDDATE'])
        listforloop.sort(reverse=True) ##newest date first, if only one date, still first
        amydate_use=listforloop[0]

        mridates=subjectdf['MRIDATE'].values.tolist()
        mridates.append(amydate_use)
        mridates.sort()      
        mriuse=[mridates[x-1] for x in range(0,len(mridates)) if mridates[x] == amydate_use]
        rowtoadd=subjectdf.loc[subjectdf['MRIDATE']==mriuse[0],:].reset_index(drop=True).squeeze()
        #add amycons to that line if not there already
        if pd.isna(rowtoadd.loc['Amyloid_consensus']):
            rowtoadd.at['Amyloid_consensus']='Negative'
            rowtoadd.at['Amyloid_Consensus_Comments']='amyloid consensus derived from different amyloid scan'
        fornewdf.append(rowtoadd)       

    
    else: ###no amyloid consensus data, keep most recent MRI date
        subjectdfsort=subjectdf.sort_values('MRIDATE',ascending=False) ##biggest/most recent first 
        subjectdfsort.reset_index(drop=True,inplace=True)
        rowtoadd=subjectdfsort.iloc[0,:]            
        fornewdf.append(rowtoadd)

        
##outside for loop:
newmridf=pd.DataFrame(fornewdf)
newmridf.reset_index(drop=True,inplace=True)
newmridf.info()
# Out:
# /var/folders/p8/czc1tc6x0t9d8stjlfnm009c0000gn/T/ipykernel_19688/1956860461.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rowtoadd.at['Amyloid_consensus']='Positive'
# /var/folders/p8/czc1tc6x0t9d8stjlfnm009c0000gn/T/ipykernel_19688/1956860461.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rowtoadd.at['Amyloid_Consensus_Comments']='amyloid consensus derived from previous scans'
# /var/folders/p8/czc1tc6x0t9d8stjlfnm009c0000gn/T/ipykernel_19688/1956860461.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subjectdf.sort_values('MRIDATE',ascending=False,inplace=True)
# /var/folders/p8/czc1tc6x0t9d8stjlfnm009c0000gn/T/ipykernel_19688/1956860461.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rowtoadd.at['Amyloid_consensus']='Positive'
# /var/folders/p8/czc1tc6x0t9d8stjlfnm009c0000gn/T/ipykernel_19688/1956860461.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rowtoadd.at['Amyloid_Consensus_Comments']='amyloid consensus derived from previous scans'
# /var/folders/p8/czc1tc6x0t9d8stjlfnm009c0000gn/T/ipykernel_19688/1956860461.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subjectdf.sort_values('MRIDATE',ascending=False,inplace=True)
# /var/folders/p8/czc1tc6x0t9d8stjlfnm009c0000gn/T/ipykernel_19688/1956860461.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rowtoadd.at['Amyloid_consensus']='Positive'
# /var/folders/p8/czc1tc6x0t9d8stjlfnm009c0000gn/T/ipykernel_19688/1956860461.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rowtoadd.at['Amyloid_Consensus_Comments']='amyloid consensus derived from previous scans'
# /var/folders/p8/czc1tc6x0t9d8stjlfnm009c0000gn/T/ipykernel_19688/1956860461.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subjectdf.sort_values('MRIDATE',ascending=False,inplace=True)
# /var/folders/p8/czc1tc6x0t9d8stjlfnm009c0000gn/T/ipykernel_19688/1956860461.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rowtoadd.at['Amyloid_consensus']='Positive'
# /var/folders/p8/czc1tc6x0t9d8stjlfnm009c0000gn/T/ipykernel_19688/1956860461.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rowtoadd.at['Amyloid_Consensus_Comments']='amyloid consensus derived from previous scans'
# /var/folders/p8/czc1tc6x0t9d8stjlfnm009c0000gn/T/ipykernel_19688/1956860461.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subjectdf.sort_values('MRIDATE',ascending=False,inplace=True)
# /var/folders/p8/czc1tc6x0t9d8stjlfnm009c0000gn/T/ipykernel_19688/1956860461.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rowtoadd.at['Amyloid_consensus']='Positive'
# /var/folders/p8/czc1tc6x0t9d8stjlfnm009c0000gn/T/ipykernel_19688/1956860461.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rowtoadd.at['Amyloid_Consensus_Comments']='amyloid consensus derived from previous scans'
# uh-oh
# 122714
#       MRIDATE  AMYLOIDDATE Amyloid_consensus  \
# 377  20180119   20181106.0      Inconclusive
#
#                             Amyloid_Consensus_Comments
# 377  Amyloid consensus inconclusive until processin...
# uh-oh
# 123343
#       MRIDATE  AMYLOIDDATE Amyloid_consensus  \
# 414  20210504   20210310.0          Positive
# 413  20191223   20191212.0          Negative
# 412  20181130   20181205.0          Positive
#
#                             Amyloid_Consensus_Comments
# 414  Amyloid consensus used quantitative result, Cl...
# 413  Amyloid consensus used quantitative result, Cl...
# 412  Amyloid consensus used quantitative result, Cl...
# uh-oh
# 123928
#       MRIDATE  AMYLOIDDATE Amyloid_consensus Amyloid_Consensus_Comments
# 449  20220707   20220413.0          Positive                        NaN
# 448  20190123   20190424.0          Negative                        NaN
# uh-oh
# 125300
#       MRIDATE  AMYLOIDDATE Amyloid_consensus  \
# 573  20211026   20211215.0          Positive
# 572  20201116   20201111.0      Inconclusive
# 571  20190820   20190905.0          Positive
#
#                             Amyloid_Consensus_Comments
# 573  Amyloid consensus used quantitative result, Cl...
# 572  Amyloid consensus inconclusive until processin...
# 571  Amyloid consensus used quantitative result, Cl...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 484 entries, 0 to 483
# Columns: 286 entries, INDD to Amyloid_Consensus_Comments
# dtypes: float64(248), int64(2), object(36)
# memory usage: 1.1+ MB

# %%
newmridf[newmridf.duplicated(['INDD'],keep=False)]
# Out:
# Empty DataFrame
# Columns: [INDD, MRIDATE, ScanType, ICV_ASHST1_3T, L_Modi_Rater_T1_3T, R_Modi_Rater_T1_3T, QC_MRI_T1, QC_ICV_T1, QC_Seg_left_usegray_ASHST1_3T, QC_Seg_right_usegray_ASHST1_3T, QC_Edits_left_ASHST1_3T, QC_Edits_right_ASHST1_3T, QC_Exclude_left_ASHST1_3T, QC_Exclude_right_ASHST1_3T, QC_CheckOrigSpace_ASHST1_3T, L_AHippo_VOL_ASHST1_3T, L_PHippo_VOL_ASHST1_3T, L_ERC_VOL_ASHST1_3T, L_BA35_VOL_ASHST1_3T, L_BA36_VOL_ASHST1_3T, L_PHC_VOL_ASHST1_3T, R_AHippo_VOL_ASHST1_3T, R_PHippo_VOL_ASHST1_3T, R_ERC_VOL_ASHST1_3T, R_BA35_VOL_ASHST1_3T, R_BA36_VOL_ASHST1_3T, R_PHC_VOL_ASHST1_3T, M_AHippo_VOL_ASHST1_3T, M_PHippo_VOL_ASHST1_3T, M_ERC_VOL_ASHST1_3T, M_BA35_VOL_ASHST1_3T, M_BA36_VOL_ASHST1_3T, M_PHC_VOL_ASHST1_3T, L_Hippo_MeanTHK_MSTTHKMT_ASHST1_3T, L_ERC_MeanTHK_MSTTHKMT_ASHST1_3T, L_BA35_MeanTHK_MSTTHKMT_ASHST1_3T, L_BA36_MeanTHK_MSTTHKMT_ASHST1_3T, L_PHC_MeanTHK_MSTTHKMT_ASHST1_3T, L_Hippo_MedianTHK_MSTTHKMT_ASHST1_3T, L_ERC_MedianTHK_MSTTHKMT_ASHST1_3T, L_BA35_MedianTHK_MSTTHKMT_ASHST1_3T, L_BA36_MedianTHK_MSTTHKMT_ASHST1_3T, L_PHC_MedianTHK_MSTTHKMT_ASHST1_3T, R_Hippo_MeanTHK_MSTTHKMT_ASHST1_3T, R_ERC_MeanTHK_MSTTHKMT_ASHST1_3T, R_BA35_MeanTHK_MSTTHKMT_ASHST1_3T, R_BA36_MeanTHK_MSTTHKMT_ASHST1_3T, R_PHC_MeanTHK_MSTTHKMT_ASHST1_3T, R_Hippo_MedianTHK_MSTTHKMT_ASHST1_3T, R_ERC_MedianTHK_MSTTHKMT_ASHST1_3T, R_BA35_MedianTHK_MSTTHKMT_ASHST1_3T, R_BA36_MedianTHK_MSTTHKMT_ASHST1_3T, R_PHC_MedianTHK_MSTTHKMT_ASHST1_3T, M_Hippo_MeanTHK_MSTTHKMT_ASHST1_3T, M_ERC_MeanTHK_MSTTHKMT_ASHST1_3T, M_BA35_MeanTHK_MSTTHKMT_ASHST1_3T, M_BA36_MeanTHK_MSTTHKMT_ASHST1_3T, M_PHC_MeanTHK_MSTTHKMT_ASHST1_3T, M_Hippo_MedianTHK_MSTTHKMT_ASHST1_3T, M_ERC_MedianTHK_MSTTHKMT_ASHST1_3T, M_BA35_MedianTHK_MSTTHKMT_ASHST1_3T, M_BA36_MedianTHK_MSTTHKMT_ASHST1_3T, M_PHC_MedianTHK_MSTTHKMT_ASHST1_3T, L_BA35BA36_MeanTHK_MSTTHKMT_ASHST1_3T, L_BA35BA36_MedianTHK_MSTTHKMT_ASHST1_3T, R_BA35BA36_MeanTHK_MSTTHKMT_ASHST1_3T, R_BA35BA36_MedianTHK_MSTTHKMT_ASHST1_3T, M_BA35BA36_MeanTHK_MSTTHKMT_ASHST1_3T, M_BA35BA36_MedianTHK_MSTTHKMT_ASHST1_3T, L_Hippo_MedianTHK_MSTFitQuality_ASHST1_3T, L_ERC_MedianTHK_MSTFitQuality_ASHST1_3T, L_BA35_MedianTHK_MSTFitQuality_ASHST1_3T, L_BA36_MedianTHK_MSTFitQuality_ASHST1_3T, L_PHC_MedianTHK_MSTFitQuality_ASHST1_3T, L_ALL_MedianTHK_MSTFitQuality_ASHST1_3T, R_Hippo_MedianTHK_MSTFitQuality_ASHST1_3T, R_ERC_MedianTHK_MSTFitQuality_ASHST1_3T, R_BA35_MedianTHK_MSTFitQuality_ASHST1_3T, R_BA36_MedianTHK_MSTFitQuality_ASHST1_3T, R_PHC_MedianTHK_MSTFitQuality_ASHST1_3T, R_ALL_MedianTHK_MSTFitQuality_ASHST1_3T, L_Modi_Rater_T2_3T, R_Modi_Rater_T2_3T, L_QA1_ASHST2_3T, L_QA2_ASHST2_3T, L_QA3_ASHST2_3T, L_QA_COMMENT_ASHST2_3T, R_QA1_ASHST2_3T, R_QA2_ASHST2_3T, R_QA3_ASHST2_3T, R_QA_COMMENT_ASHST2_3T, L_CA1_NSlice_ASHST2_3T, L_CA2_NSlice_ASHST2_3T, L_DG_NSlice_ASHST2_3T, L_CA3_NSlice_ASHST2_3T, L_Tail_NSlice_ASHST2_3T, L_SUB_NSlice_ASHST2_3T, L_ERC_NSlice_ASHST2_3T, L_BA35_NSlice_ASHST2_3T, L_BA36_NSlice_ASHST2_3T, ...]
# Index: []
#
# [0 rows x 286 columns]

# %%
newmridf
# Out:
#        INDD   MRIDATE ScanType  ICV_ASHST1_3T L_Modi_Rater_T1_3T  \
# 0    100049  20160621    MRI3T    1391467.887               None
# 1    100113  20180821    MRI3T    1099951.379               None
# 2    100437  20210708    MRI3T    1428884.949               None
# 3    100639  20200220    MRI3T    1506277.843               None
# 4    100790  20171219    MRI3T    2008037.705                RDF
# ..      ...       ...      ...            ...                ...
# 479  128922  20220728    MRI3T    1429340.629               None
# 480  128953  20221013    MRI3T    1281508.000               None
# 481  128983  20221020    MRI3T    1532433.000               None
# 482  128986  20220818    MRI3T    1752526.284               None
# 483  129131  20220818    MRI3T    1477261.268               None
#
#     R_Modi_Rater_T1_3T  QC_MRI_T1 QC_ICV_T1 QC_Seg_left_usegray_ASHST1_3T  \
# 0                 None        NaN        ok          H+PHC ok rest misseg
# 1                 None        NaN       NaN                         ok; H
# 2                 None        NaN       NaN                           NaN
# 3                 None        NaN       NaN                            ok
# 4                  RDF        NaN        ok  H overseg PHC ok rest misseg
# ..                 ...        ...       ...                           ...
# 479               None        NaN       NaN                           NaN
# 480               None        NaN       NaN                           NaN
# 481               None        NaN       NaN                           NaN
# 482               None        NaN       NaN                           NaN
# 483               None        NaN       NaN                           NaN
#
#     QC_Seg_right_usegray_ASHST1_3T  ... CDRSum Behavior Language  \
# 0             H+PHC ok rest misseg  ...    0.0      0.0      0.0
# 1                              ok   ...    0.5      0.0      0.5
# 2                              NaN  ...    4.0      0.0      0.5
# 3                               ok  ...    0.0      0.0      0.0
# 4            H overseg rest misseg  ...    5.0      0.0      0.5
# ..                             ...  ...    ...      ...      ...
# 479                            NaN  ...    NaN      NaN      NaN
# 480                            NaN  ...    NaN      NaN      NaN
# 481                            NaN  ...    NaN      NaN      NaN
# 482                            NaN  ...    NaN      NaN      NaN
# 483                            NaN  ...    NaN      NaN      NaN
#
#     SupplimentTotal CDRTotal  GlobalCDR  END  date_diff_rough  \
# 0               0.0      0.0        0.0   -1          20006.0
# 1               0.5      1.0        0.5   -1            392.0
# 2               0.5      4.5        1.0   -1            123.0
# 3               0.0      0.0        0.0   -1              NaN
# 4               0.5      5.5        1.0   -1              NaN
# ..              ...      ...        ...  ...              ...
# 479             NaN      NaN        NaN   -1            284.0
# 480             NaN      NaN        NaN   -1              NaN
# 481             NaN      NaN        NaN   -1              NaN
# 482             NaN      NaN        NaN   -1            110.0
# 483             NaN      NaN        NaN   -1            200.0
#
#      Amyloid_consensus                         Amyloid_Consensus_Comments
# 0             Negative                                                NaN
# 1             Negative                                                NaN
# 2             Positive                                                NaN
# 3                  NaN                                                NaN
# 4                  NaN                                                NaN
# ..                 ...                                                ...
# 479           Negative                                                NaN
# 480                NaN                                                NaN
# 481                NaN                                                NaN
# 482           Positive                                                NaN
# 483           Negative  Amyloid consensus used quantitative result, Cl...
#
# [484 rows x 286 columns]

# %%
newmridf.to_csv('ABC_MRI3T_ASHST1T2_measurements_20230109_based_on_Amy_consensus.csv',index=False,header=True)
